# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import array_to_latex

def print_circuit(state):
    print("=================================")
    print("state = " + state)
    circuit = QuantumCircuit(2)
    circuit.initialize(Statevector.from_label(state).data, [0, 1])
    circuit.h(0)
    circuit.cx(0, 1)
    display(circuit.draw('mpl'))
    state_vector = Statevector.from_instruction(circuit)
    display(state_vector.draw('latex'))
    display(array_to_latex(state_vector))
    display(state_vector.draw('qsphere'))

# %%
states = [format(x, f'0{2}b') for x in range(2 ** 2)]
print(states)
# Out:
# ['00', '01', '10', '11']

# %%
for state in states:
    print_circuit(state)
# Out:
# ...
# state = 00
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$
# $$
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & 0 & 0 & \tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$
# ...
# state = 01
# $$\frac{\sqrt{2}}{2} |00\rangle- \frac{\sqrt{2}}{2} |11\rangle$$
# $$
#
# \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} & 0 & 0 & -\tfrac{1}{\sqrt{2}}  \\
#  \end{bmatrix}
# $$
# ...
# state = 10
# $$None |00\rangle\frac{\sqrt{2}}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangleNone |11\rangle$$
# $$
#
# \begin{bmatrix}
# 0 & \tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}} & 0  \\
#  \end{bmatrix}
# $$
# ...
# state = 11
# $$None |00\rangle- \frac{\sqrt{2}}{2} |01\rangle+\frac{\sqrt{2}}{2} |10\rangleNone |11\rangle$$
# $$
#
# \begin{bmatrix}
# 0 & -\tfrac{1}{\sqrt{2}} & \tfrac{1}{\sqrt{2}} & 0  \\
#  \end{bmatrix}
# $$
